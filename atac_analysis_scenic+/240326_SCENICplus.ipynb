# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('../data/Kdm6aKO_ALL_GEX-CB_scANVI-CellTypes_ctl240117.raw.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 46135 × 32285
#     obs: 'cell_source', 'cell_type', 'donor', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'cell_states', 'seed_labels', 'genotype', 'group', 'file', 'batch', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'genome', 'modality', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 46135 × 32285
#     obs: 'cell_source', 'cell_type', 'donor', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'cell_states', 'seed_labels', 'genotype', 'group', 'file', 'batch', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'genome', 'modality', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
adata.obs['C_scANVI'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
adata.obs.columns.tolist()
# Out:
# ['cell_source',
#  'cell_type',
#  'donor',
#  'n_counts',
#  'n_genes',
#  'percent_mito',
#  'percent_ribo',
#  'region',
#  'sample',
#  'scrublet_score',
#  'cell_states',
#  'seed_labels',
#  'genotype',
#  'group',
#  'file',
#  'batch',
#  'doublet_scores',
#  'n_genes_by_counts',
#  'total_counts',
#  'total_counts_mt',
#  'pct_counts_mt',
#  'total_counts_ribo',
#  'pct_counts_ribo',
#  'percent_mt2',
#  'percent_chrY',
#  'XIST-counts',
#  'S_score',
#  'G2M_score',
#  '_scvi_batch',
#  '_scvi_labels',
#  'C_scANVI']

# %%
sc.pl.umap(adata, color=['C_scANVI', 'group', 'sample', 'batch'], ncols=3, wspace=0.8)
# Out:
# /home/ceger/miniforge3/envs/heart_multiome-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/ceger/miniforge3/envs/heart_multiome-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/ceger/miniforge3/envs/heart_multiome-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/ceger/miniforge3/envs/heart_multiome-env/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
